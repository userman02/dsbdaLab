# %%
import pandas as pd

# Load the forest fire dataset
forest_fire_data = pd.read_csv('C:\\Users\\acer\\Downloads\\archive (8)\\forestfires.csv')
forest_fire_data
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
# Display the first few rows of the dataset......this is data analysis.....1-explore data
print(forest_fire_data.head())
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
# Get information about the dataset
print(forest_fire_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB
# None

# %%
# Calculate basic statistics of the dataset
print(forest_fire_data.describe())
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %%
# Check for missing values
print(forest_fire_data.isnull().sum())
# Out:
# X        0
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %%
import matplotlib.pyplot as plt  #2-visualize data
import seaborn as sns

# %%
# Plot the distribution of the target variable (e.g., 'area')
plt.figure(figsize=(8, 6))
sns.histplot(data=forest_fire_data, x='area', bins=20)
plt.title('Distribution of Forest Fire Area')
plt.xlabel('Area')
plt.ylabel('Count')
plt.show()

# %%
# Plot the correlation matrix of the dataset
plt.figure(figsize=(10, 8))
sns.heatmap(forest_fire_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_14728\2398436087.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(forest_fire_data.corr(), annot=True, cmap='coolwarm')

# %%
# data mining 1) feature selection
# Select relevant features for analysis
selected_features = ['temp', 'RH', 'wind', 'rain', 'area']
forest_fire_subset = forest_fire_data[selected_features]

# %%
forest_fire_subset
# Out:
#      temp  RH  wind  rain   area
# 0     8.2  51   6.7   0.0   0.00
# 1    18.0  33   0.9   0.0   0.00
# 2    14.6  33   1.3   0.0   0.00
# 3     8.3  97   4.0   0.2   0.00
# 4    11.4  99   1.8   0.0   0.00
# ..    ...  ..   ...   ...    ...
# 512  27.8  32   2.7   0.0   6.44
# 513  21.9  71   5.8   0.0  54.29
# 514  21.2  70   6.7   0.0  11.16
# 515  25.6  42   4.0   0.0   0.00
# 516  11.8  31   4.5   0.0   0.00
#
# [517 rows x 5 columns]

# %%
#clustering
from sklearn.cluster import KMeans

# Perform clustering using K-means algorithm
kmeans = KMeans(n_clusters=3, random_state=42)
forest_fire_clustered = forest_fire_subset.copy()
forest_fire_clustered['cluster'] = kmeans.fit_predict(forest_fire_subset)
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
forest_fire_clustered['cluster']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 512    0
# 513    0
# 514    0
# 515    0
# 516    0
# Name: cluster, Length: 517, dtype: int32

# %%
# Print the cluster centers
print(kmeans.cluster_centers_)
# Out:
# [[1.87731076e+01 4.45239044e+01 4.02569721e+00 2.23107570e-02
#   5.65519920e+00]
#  [2.63000000e+01 2.70000000e+01 4.45000000e+00 0.00000000e+00
#   9.18560000e+02]
#  [2.22307692e+01 3.78461538e+01 3.63846154e+00 0.00000000e+00
#   1.51232308e+02]]

# %%
# Visualize the clusters
sns.scatterplot(data=forest_fire_clustered, x='temp', y='RH', hue='cluster')
plt.title('Clusters of Forest Fire Data')
plt.xlabel('Temperature')
plt.ylabel('Relative Humidity')
plt.show()
