# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
df =  pd.read_csv('C:\\Users\\acer\\Downloads\\archive (5)\\dataset_Facebook.csv',sep=";")
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
temp1 = df.loc[10:25]
temp1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 10            139441  Status         2          12             5         10
# 11            139441   Photo         2          12             5         10
# 12            139441   Photo         2          12             5         10
# 13            139441   Photo         2          12             5          3
# 14            138414   Photo         2          12             4          5
# 15            138414  Status         2          12             3         10
# 16            138414   Photo         3          12             3          3
# 17            138414   Photo         1          12             2         12
# 18            138414  Status         3          12             2          3
# 19            138414   Photo         3          12             1         11
# 20            138414   Photo         2          12             1          3
# ...

# %%
subset = df.loc[df['Type'] == 'photo']
subset
# Out:
# Empty DataFrame
# Columns: [Page total likes, Type, Category, Post Month, Post Weekday, Post Hour, Paid, Lifetime Post Total Reach, Lifetime Post Total Impressions, Lifetime Engaged Users, Lifetime Post Consumers, Lifetime Post Consumptions, Lifetime Post Impressions by people who have liked your Page, Lifetime Post reach by people who like your Page, Lifetime People who have liked your Page and engaged with your post, comment, like, share, Total Interactions]
# Index: []

# %%
subset1 = df.loc[df['Category'] == '2']
subset1
# Out:
# Empty DataFrame
# Columns: [Page total likes, Type, Category, Post Month, Post Weekday, Post Hour, Paid, Lifetime Post Total Reach, Lifetime Post Total Impressions, Lifetime Engaged Users, Lifetime Post Consumers, Lifetime Post Consumptions, Lifetime Post Impressions by people who have liked your Page, Lifetime Post reach by people who like your Page, Lifetime People who have liked your Page and engaged with your post, comment, like, share, Total Interactions]
# Index: []

# %%
subset = df[['Type', 'Category']]
subset
# Out:
#        Type  Category
# 0     Photo         2
# 1    Status         2
# 2     Photo         3
# 3     Photo         2
# 4     Photo         2
# ..      ...       ...
# 495   Photo         3
# 496   Photo         2
# 497   Photo         1
# 498   Photo         3
# 499   Photo         2
#
# [500 rows x 2 columns]

# %%
df1 = df[['Type', 'Category', 'comment']].loc[4:17]
df2 = df[['Type', 'Category', 'Paid']].loc[24:30]
df3 = df[['Type', 'Category', 'Paid']].loc[31:35]
pd.concat([df1, df2, df3])
# Out:
#       Type  Category  comment  Paid
# 4    Photo         2     19.0   NaN
# 5   Status         2      1.0   NaN
# 6    Photo         3      3.0   NaN
# 7    Photo         3      0.0   NaN
# 8   Status         2      0.0   NaN
# 9    Photo         3      3.0   NaN
# 10  Status         2      0.0   NaN
# 11   Photo         2      0.0   NaN
# 12   Photo         2      0.0   NaN
# 13   Photo         2      5.0   NaN
# 14   Photo         2      2.0   NaN
# 15  Status         2      4.0   NaN
# 16   Photo         3      2.0   NaN
# 17   Photo         1     15.0   NaN
# 24  Status         2      NaN   0.0
# 25  Status         2      NaN   0.0
# 26  Status         2      NaN   0.0
# 27   Photo         3      NaN   0.0
# 28   Photo         2      NaN   0.0
# 29   Video         1      NaN   1.0
# 30   Photo         2      NaN   0.0
# 31   Photo         2      NaN   0.0
# 32   Photo         3      NaN   0.0
# 33   Photo         3      NaN   0.0
# 34   Photo         1      NaN   0.0
# ...

# %%
df1 = df[['Type', 'Category', 'comment']]
df2 = df[['Type', 'Category', 'Paid']]#this is also merging of data
merged_df = pd.merge(df1, df2, on='Type')
merged_df
# Out:
#          Type  Category_x  comment  Category_y  Paid
# 0       Photo           2        4           2   0.0
# 1       Photo           2        4           3   0.0
# 2       Photo           2        4           2   1.0
# 3       Photo           2        4           2   0.0
# 4       Photo           2        4           3   1.0
# ...       ...         ...      ...         ...   ...
# 184029  Video           1       23           1   1.0
# 184030  Video           1       23           1   0.0
# 184031  Video           1       23           1   0.0
# 184032  Video           1       23           1   1.0
# 184033  Video           1       23           1   0.0
#
# [184034 rows x 5 columns]

# %%
df.sort_values(['Category', 'Paid'], ascending=False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 6              139441  Photo         3          12             1          3
# 7              139441  Photo         3          12             7          9
# 83             137177  Photo         3          11             5         10
# 143            136013  Photo         3          10             2         10
# 167            135428  Photo         3           9             4          2
# ..                ...    ...       ...         ...           ...        ...
# 474             91009  Photo         1           2             1         12
# 477             86909   Link         1           1             6          4
# 485             86491   Link         1           1             2          2
# 492             85979   Link         1           1             5         11
# 497             81370  Photo         1           1             5          2
#
# ...

# %%
df.sort_values(['Category', 'Paid'], ascending=True)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 22             138414   Link         1          12             7         10
# 34             138895  Photo         1          12             2          3
# 39             138895  Photo         1          12             7          3
# 42             138353  Photo         1          12             5         10
# ..                ...    ...       ...         ...           ...        ...
# 462             92293  Photo         3           2             7         13
# 463             92186  Photo         3           2             7          2
# 473             91116  Photo         3           2             2          4
# 475             86909  Photo         3           1             6         16
# 491             85979  Photo         3           1             6          3
#
# ...

# %%
df.transpose()
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
pd.pivot_table(df, index=['Type', 'Category', 'Paid'], values=['like', 'comment'])
# Out:
#                         comment        like
# Type   Category Paid
# Link   1        0.0    2.428571   83.785714
#                 1.0    4.000000   56.666667
#        2        0.0    2.000000   32.000000
#        3        0.0    2.000000   68.000000
# Photo  1        0.0    5.742424  114.793893
#                 1.0    6.283019  153.698113
#        2        0.0    7.313433  154.985075
#                 1.0   24.956522  477.739130
#        3        0.0    7.205607  218.990654
#                 1.0    6.186047  221.651163
# Status 1        0.0    3.500000   99.500000
#                 1.0    6.000000  210.000000
#        2        0.0    8.068966  150.655172
#                 1.0   15.888889  285.333333
#        3        0.0    2.750000  151.500000
# Video  1        0.0   10.333333  216.000000
#                 1.0   13.750000  243.000000

# %%
num_rows, num_cols = df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_cols)
# Out:
# Number of rows: 500
# Number of columns: 19

# %%
stacked_df = df.stack()
print("Stacked DataFrame:")
print(stacked_df)
# Out:
# Stacked DataFrame:
# 0    Page total likes                                                       139441
#      Type                                                                    Photo
#      Category                                                                    2
#      Post Month                                                                 12
#      Post Weekday                                                                4
#                                                                              ...
# 499  Lifetime People who have liked your Page and engaged with your post       316
#      comment                                                                     0
#      like                                                                     91.0
#      share                                                                    28.0
#      Total Interactions                                                        119
# Length: 9494, dtype: object
