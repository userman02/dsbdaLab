# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('heart (1).csv')
df
# Out:
#       Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0      52    1          0     125   212    0        1    168      0      1.0
# 1      53    1          0     140   203    1        0    155      1      3.1
# 2      70    1          0     145   174    0        1    125      1      2.6
# 3      61    1          0     148   203    0        1    161      0      0.0
# 4      62    0          0     138   294    1        1    106      0      1.9
# ...   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 1020   59    1          1     140   221    0        1    164      1      0.0
# 1021   60    1          0     125   258    0        0    141      1      2.8
# 1022   47    1          0     110   275    0        0    118      1      1.0
# 1023   50    0          0     110   254    0        0    159      0      0.0
# 1024   54    1          0     120   188    0        1    113      0      1.4
#
#       Slope  Ca  Thal  AHD
# ...

# %%
#Data cleaning
df.isnull().sum() #checking null values
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         0
# AHD          0
# dtype: int64

# %%
droped_df1 = df1.dropna()# droping null values
droped_df1.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         0
# AHD          0
# dtype: int64

# %%
#Data Integration

# %%
df1=df[['Age','Sex','ChestPain']].loc[0:20]
df1
# Out:
#     Age  Sex  ChestPain
# 0    52    1          0
# 1    53    1          0
# 2    70    1          0
# 3    61    1          0
# 4    62    0          0
# 5    58    0          0
# 6    58    1          0
# 7    55    1          0
# 8    46    1          0
# 9    54    1          0
# 10   71    0          0
# 11   43    0          0
# 12   34    0          1
# 13   51    1          0
# 14   52    1          0
# 15   34    0          1
# 16   51    0          2
# 17   54    1          0
# 18   50    0          1
# 19   58    1          2
# 20   60    1          2

# %%
df2=df[['Age','Sex','ChestPain']].loc[21:30]
df2
# Out:
#     Age  Sex  ChestPain
# 21   67    0          0
# 22   45    1          0
# 23   63    0          2
# 24   42    0          2
# 25   61    0          0
# 26   44    1          2
# 27   58    0          1
# 28   56    1          2
# 29   55    0          0
# 30   44    1          0

# %%
df3=df[['Age','Sex','ChestPain']].loc[31:35]
df3
# Out:
#     Age  Sex  ChestPain
# 31   50    0          1
# 32   57    1          0
# 33   70    1          2
# 34   50    1          2
# 35   46    1          2

# %%
integrated_df=pd.concat([df1,df2,df3])
integrated_df
# Out:
#     Age  Sex  ChestPain
# 0    52    1          0
# 1    53    1          0
# 2    70    1          0
# 3    61    1          0
# 4    62    0          0
# 5    58    0          0
# 6    58    1          0
# 7    55    1          0
# 8    46    1          0
# 9    54    1          0
# 10   71    0          0
# 11   43    0          0
# 12   34    0          1
# 13   51    1          0
# 14   52    1          0
# 15   34    0          1
# 16   51    0          2
# 17   54    1          0
# 18   50    0          1
# 19   58    1          2
# 20   60    1          2
# 21   67    0          0
# 22   45    1          0
# 23   63    0          2
# 24   42    0          2
# 25   61    0          0
# 26   44    1          2
# 27   58    0          1
# 28   56    1          2
# 29   55    0          0
# 30   44    1          0
# 31   50    0          1
# 32   57    1          0
# 33   70    1          2
# 34   50    1          2
# 35   46    1          2

# %%
#Data Transformation

# %%
df.loc[df['Sex']==1, 'Sex']='M' #replacing 1 with M
df.loc[df['Sex']==0, 'Sex']='F'#replacing 0 with F
df.head()
# Out:
#    Age Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   52   M          0     125   212    0        1    168      0      1.0
# 1   53   M          0     140   203    1        0    155      1      3.1
# 2   70   M          0     145   174    0        1    125      1      2.6
# 3   61   M          0     148   203    0        1    161      0      0.0
# 4   62   F          0     138   294    1        1    106      0      1.9
#
#    Slope  Ca  Thal  AHD
# 0      2   2     3    0
# 1      0   0     3    0
# 2      0   0     3    0
# 3      2   1     3    0
# 4      1   3     2    0

# %%
from sklearn.preprocessing  import LabelEncoder
labelencoder=LabelEncoder()
df['Sex']=labelencoder.fit_transform(df['Sex'])
df      #used to encode categorical variables into numerical labels
# Out:
#       Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0      52    1          0     125   212    0        1    168      0      1.0
# 1      53    1          0     140   203    1        0    155      1      3.1
# 2      70    1          0     145   174    0        1    125      1      2.6
# 3      61    1          0     148   203    0        1    161      0      0.0
# 4      62    0          0     138   294    1        1    106      0      1.9
# ...   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 1020   59    1          1     140   221    0        1    164      1      0.0
# 1021   60    1          0     125   258    0        0    141      1      2.8
# 1022   47    1          0     110   275    0        0    118      1      1.0
# 1023   50    0          0     110   254    0        0    159      0      0.0
# 1024   54    1          0     120   188    0        1    113      0      1.4
#
#       Slope  Ca  Thal  AHD
# ...

# %%
df4 = pd.read_csv('AirQuality.csv',sep=';')
df4
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
#Replacing the Object dtype of Date to Date dtype
df4['Date'] = pd.to_datetime(df4['Date'])

#To Replace the Comma's with Dot
df4.replace(to_replace=',',value='.', regex=True, inplace=True)
df4
# Out:
#            Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0    2004-10-03  18.00.00    2.6       1360.0     150.0     11.9
# 1    2004-10-03  19.00.00      2       1292.0     112.0      9.4
# 2    2004-10-03  20.00.00    2.2       1402.0      88.0      9.0
# 3    2004-10-03  21.00.00    2.2       1376.0      80.0      9.2
# 4    2004-10-03  22.00.00    1.6       1272.0      51.0      6.5
# ...         ...       ...    ...          ...       ...      ...
# 9466        NaT       NaN    NaN          NaN       NaN      NaN
# 9467        NaT       NaN    NaN          NaN       NaN      NaN
# 9468        NaT       NaN    NaN          NaN       NaN      NaN
# 9469        NaT       NaN    NaN          NaN       NaN      NaN
# 9470        NaT       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df4.head()
# Out:
#         Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0 2004-10-03  18.00.00    2.6       1360.0     150.0     11.9         1046.0
# 1 2004-10-03  19.00.00      2       1292.0     112.0      9.4          955.0
# 2 2004-10-03  20.00.00    2.2       1402.0      88.0      9.0          939.0
# 3 2004-10-03  21.00.00    2.2       1376.0      80.0      9.2          948.0
# 4 2004-10-03  22.00.00    1.6       1272.0      51.0      6.5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13.6  48.9
# 1    103.0        1174.0     92.0        1559.0        972.0  13.3  47.7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11.9  54.0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11.0  60.0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11.2  59.6
#
#        AH  Unnamed: 15  Unnamed: 16
# ...

# %%
#error correction

# %%
df[df['Ca']==4]
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 52    38    1          2     138   175    0        1    173      0      0.0
# 83    38    1          2     138   175    0        1    173      0      0.0
# 128   52    1          2     138   223    0        1    169      0      0.0
# 208   38    1          2     138   175    0        1    173      0      0.0
# 242   38    1          2     138   175    0        1    173      0      0.0
# 290   52    1          2     138   223    0        1    169      0      0.0
# 340   38    1          2     138   175    0        1    173      0      0.0
# 348   43    1          0     132   247    1        0    143      1      0.1
# 417   52    1          2     138   223    0        1    169      0      0.0
# 428   43    1          0     132   247    1        0    143      1      0.1
# 465   38    1          2     138   175    0        1    173      0      0.0
# ...

# %%
df.loc[df['Ca']==4,'Ca']=np.NaN   #It locates the rows where the value in the 'ca' column is equal to 4 and replaces those values with NaN (Not a Number)

# %%
df = df.fillna(df.median())
#The statement df = df.fillna(df.median()) fills the missing values in DataFrame1 with the median value of each column.

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         0
# AHD          0
# dtype: int64

# %%
df
# Out:
#       Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0      52    1          0     125   212    0        1    168      0      1.0
# 1      53    1          0     140   203    1        0    155      1      3.1
# 2      70    1          0     145   174    0        1    125      1      2.6
# 3      61    1          0     148   203    0        1    161      0      0.0
# 4      62    0          0     138   294    1        1    106      0      1.9
# ...   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 1020   59    1          1     140   221    0        1    164      1      0.0
# 1021   60    1          0     125   258    0        0    141      1      2.8
# 1022   47    1          0     110   275    0        0    118      1      1.0
# 1023   50    0          0     110   254    0        0    159      0      0.0
# 1024   54    1          0     120   188    0        1    113      0      1.4
#
#       Slope   Ca  Thal  AHD
# ...

# %%
#Data model Building
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
x = df.drop(['AHD', 'Sex'], axis=1)
y = df['AHD']

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

model = LogisticRegression(max_iter=1000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Make Prediction on the test set
y_pred = model.predict(x_test)

# %%
accuracy = model.score(x_train, y_train)
accuracy
# Out:
# 0.8646341463414634
